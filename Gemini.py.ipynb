# %%
# !pip install -U -q "google-generativeai>=0.7.2"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.0/760.0 kB 14.6 MB/s eta 0:00:00

# %%
import google.generativeai as genai
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('models/gemini-1.5-flash')
response = model.generate_content("What is generative ai.")
print(response.text)
# Out:
# ## Generative AI: The Creative Machines
#
# Generative AI is a fascinating field of Artificial Intelligence that focuses on **creating** new content, rather than just analyzing existing data. It's like giving AI a blank canvas and letting it paint its own masterpiece!
#
# Here's a breakdown:
#
# **How it works:**
#
# * **Learning from Data:** Generative AI models are trained on vast amounts of data, like text, images, audio, and code. This data helps them understand patterns and relationships within that information.
# * **Generating New Content:**  Once trained, the AI can use its understanding to generate new content that is similar in style and structure to the data it learned from.
#
# **Types of Generative AI:**
#
# There are many different types of generative AI, each specializing in creating different types of content:
#
# * **Text generation:**
#     * Chatbots (like ChatGPT)
#     * Content writing assistants
#     * Code generation
#     * Summarization tools
# * **Image generation:**
#     * Image editing tools (like DALL-E 2)
#     * Creating art and design
#     * Creating realistic photorealistic images
# * **Audio generation:**
#     * Music composition
#     * Voice cloning
#     * Sound effects generation
# * **Video generation:**
#     * Creating animations
#     * Generating video content
#
# **Applications:**
#
# Generative AI has a wide range of applications, including:
#
# * **Creative industries:**  Art, music, design, and writing
# * **Business:**  Content marketing, customer service, and product development
# * **Education:**  Personalized learning experiences and educational content creation
# * **Research:**  Scientific discovery and data analysis
#
# **Examples:**
#
# * **ChatGPT:** A conversational AI that can generate human-like text and answer questions.
# * **DALL-E 2:** An image generation tool that can create realistic images from text descriptions.
# * **Jukebox:** An AI that can generate music in different genres.
# * **Stable Diffusion:** A powerful open-source image generation model.
#
# **The Future of Generative AI:**
#
# Generative AI is still a relatively new field, but it is developing rapidly.  It has the potential to revolutionize many industries and aspects of our lives. As the technology advances, we can expect to see even more creative and innovative applications emerge.
#
# **In short, generative AI is like having a powerful, creative partner that can help you generate new ideas and content across various domains. It's a rapidly growing field with vast potential to reshape the world around us.**
